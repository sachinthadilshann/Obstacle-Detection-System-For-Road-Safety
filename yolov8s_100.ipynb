# %%
# !pip install comet_ml
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 586.4/586.4 kB 6.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 18.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 7.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 249.2/249.2 kB 23.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 137.9/137.9 kB 17.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.3/54.3 kB 8.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 512.2/512.2 kB 22.4 MB/s eta 0:00:00
# ...
#   Attempting uninstall: websocket-client
#     Found existing installation: websocket-client 1.6.4
#     Uninstalling websocket-client-1.6.4:
#       Successfully uninstalled websocket-client-1.6.4
#   Attempting uninstall: python-box
#     Found existing installation: python-box 7.1.1
#     Uninstalling python-box-7.1.1:
#       Successfully uninstalled python-box-7.1.1
# ...

# %%
from comet_ml import Experiment

# Create an experiment with your api key
experiment = Experiment(
    api_key="B6kk6sWGWDwoRSovjKmFWpdDU",
    project_name="general",
    workspace="sachinthadilshann",
)
# Out:
# COMET WARNING: As you are running in a Jupyter environment, you will need to call `experiment.end()` when finished to ensure all metrics and code are logged before exiting.
# COMET INFO: Couldn't find a Git repository in '/content' nor in any parent directory. Set `COMET_GIT_DIRECTORY` if your Git Repository is elsewhere.
# COMET INFO: Experiment is live on comet.com https://www.comet.com/sachinthadilshann/general/068385a70bd447d19f672ce85c3aa229

# %%
# !nvidia-smi
# Out:
# Thu Nov 23 04:48:13 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.105.17   Driver Version: 525.105.17   CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   34C    P8     9W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
! unzip /content/drive/MyDrive/Research_Project/Finaldata.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: Finaldata/train/labels/68_JPG_jpg.rf.dbda03145db4e1dee0fadd24aa6f95c1.txt
#   inflating: Finaldata/train/labels/6alkr00kmx_Asian_Elephants_WW252891_jpg.rf.dfec595f8fb55acd7904703aad685912.txt
#   inflating: Finaldata/train/labels/6ba08eb4f283e4ed_jpg.rf.f7397a05c47b00571648975e897ff2ae.txt
#   inflating: Finaldata/train/labels/6UXTVRPZCVASDFNYCOTASKER4M_jpg.rf.6711ba9094f402b7f49413d05dc006fc.txt
#   inflating: Finaldata/train/labels/7513277910_0637bdd3ef_o_jpg.rf.19d7c628e376c260a75c71319125f5f7.txt
#   inflating: Finaldata/train/labels/77308130_jpg.rf.0fb842cc55a2d7385e4a71219575146d.txt
#   inflating: Finaldata/train/labels/779_jpeg_jpg.rf.e0959e04697bc49283f1b3a4d70f8494.txt
#   inflating: Finaldata/train/labels/7db827fb-e15d-4315-9f0a-16c8d38f9d5c_1920x1080_jpg.rf.8895dd25c512b308cc2e1629704cb473.txt
# ...

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 645.7/645.7 kB 9.1 MB/s eta 0:00:00
# ...

# %%
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.216 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 27.5/78.2 GB disk)

# %%
# !yolo detect train model=yolov8s.pt data=/content/Finaldata/data.yaml epochs=100
# Out:
# ...
# 100% 21.5M/21.5M [00:00<00:00, 184MB/s]
# Ultralytics YOLOv8.0.216 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
import glob
from IPython.display import Image, display

# Include both jpg and png files
image = ['jpg', 'jpeg', 'png']

for image_extension in image:
    for imageName in glob.glob(f'/content/runs/detect/train2*.png'):
        display(Image(filename=imageName))
        print("\n")

# %%
# !yolo task=detect mode=predict model=/content/runs/detect/train/weights/best.pt source="/content/Finaldata/test"
# Out:
# Ultralytics YOLOv8.0.216 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 11128680 parameters, 0 gradients, 28.5 GFLOPs
#
# image 1/43 /content/Finaldata/test/1.jpeg: 448x640 1 Elephant, 192.4ms
# image 2/43 /content/Finaldata/test/10.jpeg: 448x640 2 Cows, 13.0ms
# image 3/43 /content/Finaldata/test/11.jpeg: 640x608 1 Cow, 100.9ms
# image 4/43 /content/Finaldata/test/12.jpeg: 640x640 1 Dog, 17.3ms
# image 5/43 /content/Finaldata/test/13.jpeg: 448x640 2 Dogs, 1 Bufflow, 13.8ms
# image 6/43 /content/Finaldata/test/14.jpeg: 384x640 1 Dog, 108.5ms
# image 7/43 /content/Finaldata/test/15.jpeg: 480x640 2 Dogs, 105.9ms
# image 8/43 /content/Finaldata/test/16.jpeg: 448x640 3 Persons, 13.9ms
# image 9/43 /content/Finaldata/test/17.jpeg: 640x448 1 Person, 106.6ms
# image 10/43 /content/Finaldata/test/18.jpeg: 512x640 1 Bufflow, 110.5ms
# image 11/43 /content/Finaldata/test/19.jpeg: 448x640 1 Bufflow, 13.9ms
# ...

# %%
#!yolo segment train data=coco128-seg.yaml model=/content/Finaldata/data.yaml epochs=1 imgsz=640

# %%
import glob
from IPython.display import Image, display

for imageName in glob.glob('/content/runs/detect/predict/*.jpeg'):
    display(Image(filename=imageName))
    print("\n")

# %%
# !yolo task=detect mode=predict model=/content/runs/detect/train/weights/best.pt source=/content/pothole1.mp4 imgsz = 1280
# Out:
# Ultralytics YOLOv8.0.216 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 11128680 parameters, 0 gradients, 28.5 GFLOPs
#
# video 1/1 (1/692) /content/pothole1.mp4: 736x1280 5 Potholes, 102.2ms
# video 1/1 (2/692) /content/pothole1.mp4: 736x1280 6 Potholes, 29.1ms
# video 1/1 (3/692) /content/pothole1.mp4: 736x1280 7 Potholes, 29.1ms
# video 1/1 (4/692) /content/pothole1.mp4: 736x1280 6 Potholes, 29.1ms
# video 1/1 (5/692) /content/pothole1.mp4: 736x1280 7 Potholes, 26.0ms
# video 1/1 (6/692) /content/pothole1.mp4: 736x1280 5 Potholes, 26.0ms
# video 1/1 (7/692) /content/pothole1.mp4: 736x1280 5 Potholes, 26.0ms
# video 1/1 (8/692) /content/pothole1.mp4: 736x1280 6 Potholes, 26.0ms
# video 1/1 (9/692) /content/pothole1.mp4: 736x1280 5 Potholes, 21.1ms

# %%
from google.colab import files

# %%
# !zip -r yolov8s_100.zip /content/runs

# %%
# !zip -r yolov8s_100.zip /content/runs
# Out:
# updating: content/runs/ (stored 0%)
# updating: content/runs/detect/ (stored 0%)
# updating: content/runs/detect/predict2/ (stored 0%)
# updating: content/runs/detect/predict2/pothole1.avi (deflated 0%)
# updating: content/runs/detect/predict/ (stored 0%)
# updating: content/runs/detect/predict/31.jpeg (deflated 14%)
# updating: content/runs/detect/predict/12.jpeg (deflated 5%)
# updating: content/runs/detect/predict/17.jpeg (deflated 6%)
# updating: content/runs/detect/predict/35.jpeg (deflated 4%)
# updating: content/runs/detect/predict/10.jpeg (deflated 4%)
# updating: content/runs/detect/predict/33.jpeg (deflated 6%)
# updating: content/runs/detect/predict/21.jpeg (deflated 6%)
# updating: content/runs/detect/predict/6.jpeg (deflated 6%)
# updating: content/runs/detect/predict/4.jpeg (deflated 6%)
# updating: content/runs/detect/predict/images.jpeg (deflated 6%)
# updating: content/runs/detect/predict/5.jpeg (deflated 4%)
# ...

# %%
files.download('yolov8s_100.zip')

# %%
! unzip /content/test.zip

# %%
# !yolo task=detect mode=predict model=/content/runs/detect/train2/weights/best.pt source=/content/test

# %%
import glob
from IPython.display import Image, display

for imageName in glob.glob('/content/runs/detect/predict5/*.jpg'):
    display(Image(filename=imageName))
    print("\n")
